# %% [markdown]
# <h1 id="random_generated_dataset">Crime Classification data set</h1>
#
# Let's read our own dataset for this project!

# %% [markdown]
# ### Imoprt libraries
#  the required libraries are available.

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import numpy as np 
import seaborn as sns 
import matplotlib.pylab as plt
from scipy import stats
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix

# %% [markdown]
# <div id="downloading_data">
#     <h2>Reading the Data</h2>
#     To read the data, we will use read function from panads.
# </div>

# %%
crime = pd.read_csv("New_Offense_Data_2024.csv")
codes = pd.read_csv("New_Offense_Data_2024.csv", encoding="latin1")

# %%
crime.head()
# Out:
#   Address   CaseNumber     CouncilDistrict CrimeAgainst CustomCrimeAgainst  \
# 0     NaN  24-X5909611  Council District 3       Person             Person
# 1     NaN  24-X5909638  Council District 1       Person             Person
# 2     NaN  24-X5909659  Council District 1       Person             Person
# 3     NaN  24-X5909665  Council District 2       Person             Person
# 4     NaN  24-X5909704  Council District 2       Person             Person
#
#             CustomCrimeCategory         Neighborhood OccurDate  OccurTime  \
# 0           Assault: Aggravated           Montavilla  1/1/2024        514
# 1  Assault: Simple/Intimidation  Powellhurst-Gilbert  1/1/2024        429
# 2  Assault: Simple/Intimidation            Hazelwood  1/1/2024        747
# 3  Assault: Simple/Intimidation                Cully  1/1/2024          5
# 4  Assault: Simple/Intimidation             Overlook  1/1/2024       1959
#
#     OffenseCategory  OffenseCount         OffenseType  OpenDataLat  \
# 0  Assault Offenses             1  Aggravated Assault          NaN
# 1  Assault Offenses             1      Simple Assault          NaN
# 2  Assault Offenses             1      Simple Assault          NaN
# 3  Assault Offenses             1      Simple Assault          NaN
# 4  Assault Offenses             1      Simple Assault          NaN
#
#    OpenDataLon  OpenDataX  OpenDataY ReportDate ReportMonthYear
# 0          NaN        NaN        NaN   1/1/2024    January 2024
# 1          NaN        NaN        NaN   1/1/2024    January 2024
# 2          NaN        NaN        NaN   1/1/2024    January 2024
# 3          NaN        NaN        NaN   1/1/2024    January 2024
# 4          NaN        NaN        NaN   1/1/2024    January 2024

# %% [markdown]
# ## Data Analysis and pre-processing
#  First, let us gather some basic information about the dataset.

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57143 entries, 0 to 57142
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              51962 non-null  object
#  1   CaseNumber           57143 non-null  object
#  2   CouncilDistrict      56364 non-null  object
#  3   CrimeAgainst         57143 non-null  object
#  4   CustomCrimeAgainst   57143 non-null  object
#  5   CustomCrimeCategory  57143 non-null  object
#  6   Neighborhood         56645 non-null  object
#  7   OccurDate            57143 non-null  object
#  8   OccurTime            57143 non-null  int64
#  9   OffenseCategory      57143 non-null  object
#  10  OffenseCount         57143 non-null  int64
#  11  OffenseType          57143 non-null  object
#  12  OpenDataLat          51459 non-null  float64
#  13  OpenDataLon          51459 non-null  float64
#  14  OpenDataX            51459 non-null  float64
#  15  OpenDataY            51459 non-null  float64
#  16  ReportDate           57143 non-null  object
#  17  ReportMonthYear      57143 non-null  object
# dtypes: float64(4), int64(2), object(12)
# memory usage: 7.8+ MB

# %%
print(crime.shape[0])
print(crime.columns.tolist())
print(crime.dtypes)
# Out:
# 57143
# ['Address', 'CaseNumber', 'CouncilDistrict', 'CrimeAgainst', 'CustomCrimeAgainst', 'CustomCrimeCategory', 'Neighborhood', 'OccurDate', 'OccurTime', 'OffenseCategory', 'OffenseCount', 'OffenseType', 'OpenDataLat', 'OpenDataLon', 'OpenDataX', 'OpenDataY', 'ReportDate', 'ReportMonthYear']
# Address                 object
# CaseNumber              object
# CouncilDistrict         object
# CrimeAgainst            object
# CustomCrimeAgainst      object
# CustomCrimeCategory     object
# Neighborhood            object
# OccurDate               object
# OccurTime                int64
# OffenseCategory         object
# OffenseCount             int64
# OffenseType             object
# OpenDataLat            float64
# OpenDataLon            float64
# OpenDataX              float64
# OpenDataY              float64
# ReportDate              object
# ReportMonthYear         object
# dtype: object

# %% [markdown]
# Check the null Values

# %%
crime.isnull().sum()
# Out:
# Address                5181
# CaseNumber                0
# CouncilDistrict         779
# CrimeAgainst              0
# CustomCrimeAgainst        0
# CustomCrimeCategory       0
# Neighborhood            498
# OccurDate                 0
# OccurTime                 0
# OffenseCategory           0
# OffenseCount              0
# OffenseType               0
# OpenDataLat            5684
# OpenDataLon            5684
# OpenDataX              5684
# OpenDataY              5684
# ReportDate                0
# ReportMonthYear           0
# dtype: int64

# %%
total = crime.isnull().sum().sort_values(ascending=False)
total_select = total.head(20)
total_select.plot(kind="bar", figsize = (8,6), fontsize = 10)
# Out:
# <Axes: >

# %%
print(f"عدد الصفوف المكررة قبل الحذف: {crime.duplicated().sum()}")
# Out:
# عدد الصفوف المكررة قبل الحذف: 0

# %% [markdown]
# Show the Categorical Data in OffenseCategory column

# %%
count = crime['OffenseCategory'].value_counts()
count
# Out:
# OffenseCategory
# Larceny Offenses                24873
# Assault Offenses                 7944
# Vandalism                        6833
# Motor Vehicle Theft              5424
# Burglary                         4604
# Fraud Offenses                   3056
# Robbery                          1129
# Weapon Law Violations             827
# Drug/Narcotic Offenses            694
# Sex Offenses                      555
# Arson                             301
# Counterfeiting/Forgery            260
# Prostitution Offenses             259
# Pornography/Obscene Material       69
# Kidnapping/Abduction               67
# Homicide Offenses                  67
# Animal Cruelty Offenses            46
# Embezzlement                       45
# Extortion/Blackmail                40
# Stolen Property Offenses           26
# Human Trafficking Offenses         23
# Bribery                             1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(40,10))
plt.bar(count.index, count.values, color='b' )
plt.xlabel('Target variables')
plt.ylabel('Values')
plt.title("Show classes numbers")
#plt.grid()
plt.show()

# %% [markdown]
# fill the null values by median and mode

# %%
median_lat = crime['OpenDataLat'].median()
median_lon = crime['OpenDataLon'].median()

crime['OpenDataLat'] = crime['OpenDataLat'].fillna(median_lat)
crime['OpenDataLon'] = crime['OpenDataLon'].fillna(median_lon)

print("تم ملء القيم المفقودة في أعمدة OpenDataLat و OpenDataLon بنجاح.")
# Out:
# تم ملء القيم المفقودة في أعمدة OpenDataLat و OpenDataLon بنجاح.

# %%
mode_neighborhood = crime['Neighborhood'].mode()[0]
crime['Neighborhood']=crime['Neighborhood'].fillna(mode_neighborhood)

print("تم ملء القيم المفقودة في عمود Neighborhood.")
# Out:
# تم ملء القيم المفقودة في عمود Neighborhood.

# %%
crime.isnull().sum()
# Out:
# Address                5181
# CaseNumber                0
# CouncilDistrict         779
# CrimeAgainst              0
# CustomCrimeAgainst        0
# CustomCrimeCategory       0
# Neighborhood              0
# OccurDate                 0
# OccurTime                 0
# OffenseCategory           0
# OffenseCount              0
# OffenseType               0
# OpenDataLat               0
# OpenDataLon               0
# OpenDataX              5684
# OpenDataY              5684
# ReportDate                0
# ReportMonthYear           0
# dtype: int64

# %%
crime['OccurDate'] = pd.to_datetime(crime['OccurDate'])

crime['Occur_Year'] = crime['OccurDate'].dt.year
crime['Occur_Month'] = crime['OccurDate'].dt.month
crime['Occur_Day'] = crime['OccurDate'].dt.day
crime['Occur_DayOfWeek'] = crime['OccurDate'].dt.dayofweek # (0=الاثنين, 6=الأحد)

print("تم إضافة أعمدة جديدة: Occur_Year, Occur_Month, Occur_Day, Occur_DayOfWeek.")
# Out:
# تم إضافة أعمدة جديدة: Occur_Year, Occur_Month, Occur_Day, Occur_DayOfWeek.

# %%
crime['OccurTime'] = pd.to_numeric(crime['OccurTime'], errors='coerce')


crime['Occur_Hour'] = (crime['OccurTime'] // 100).astype('Int64')

crime['Occur_Minute'] = (crime['OccurTime'] % 100).astype('Int64')

crime.drop('OccurTime', axis=1, inplace=True)

print("تم إنشاء عمودين Occur_Hour و Occur_Minute بنجاح.")
# Out:
# تم إنشاء عمودين Occur_Hour و Occur_Minute بنجاح.

# %%
columns_to_drop = [
    'CaseNumber', 'Address', 'OccurDate',  'ReportDate', 
    'ReportMonthYear', 'OpenDataX', 'OpenDataY'
]

crime.drop(columns_to_drop, axis=1, inplace=True)

print(f"تم حذف الأعمدة غير الضرورية بنجاح. عدد الأعمدة المتبقية: {crime.shape[1]}")
# Out:
# تم حذف الأعمدة غير الضرورية بنجاح. عدد الأعمدة المتبقية: 16

# %%
crime.isnull().sum()
# Out:
# CouncilDistrict        779
# CrimeAgainst             0
# CustomCrimeAgainst       0
# CustomCrimeCategory      0
# Neighborhood             0
# OffenseCategory          0
# OffenseCount             0
# OffenseType              0
# OpenDataLat              0
# OpenDataLon              0
# Occur_Year               0
# Occur_Month              0
# Occur_Day                0
# Occur_DayOfWeek          0
# Occur_Hour               0
# Occur_Minute             0
# dtype: int64

# %%
numerical_cols = ['OpenDataLat', 'OpenDataLon', 'Occur_Hour', 'Occur_Minute']

z_score = 3

for col in numerical_cols:
    crime[f'{col}_ZScore'] = np.abs(stats.zscore(crime[col], nan_policy='omit'))
    
   
    crime.loc[crime[f'{col}_ZScore'] > z_score, col] = np.nan

crime.dropna(subset=numerical_cols, inplace=True)

crime.drop([f'{col}_ZScore' for col in numerical_cols], axis=1, inplace=True)

print("✅ تم التعامل مع القيم المتطرفة (Outliers) في جميع الأعمدة الرقمية.")
# Out:
# ✅ تم التعامل مع القيم المتطرفة (Outliers) في جميع الأعمدة الرقمية.

# %%
crime.describe().round(3)
# Out:
#        OffenseCount  OpenDataLat  OpenDataLon  Occur_Year  Occur_Month  \
# count     57034.000    57034.000    57034.000   57034.000    57034.000
# mean          1.001       45.529     -122.642    2023.945        6.682
# std           0.034        0.031        0.059       0.893        3.429
# min           1.000       45.436     -122.818    1951.000        1.000
# 25%           1.000       45.515     -122.682    2024.000        4.000
# 50%           1.000       45.526     -122.660    2024.000        7.000
# 75%           1.000       45.548     -122.605    2024.000       10.000
# max           4.000       45.622     -122.468    2024.000       12.000
#
#        Occur_Day  Occur_DayOfWeek  Occur_Hour  Occur_Minute
# count  57034.000        57034.000     57034.0       57034.0
# mean      15.784            3.023      12.702        22.117
# std        8.872            1.992       6.751        18.873
# min        1.000            0.000         0.0           0.0
# 25%        8.000            1.000         8.0           0.0
# 50%       16.000            3.000        14.0          21.0
# 75%       23.000            5.000        18.0          38.0
# max       31.000            6.000        23.0          59.0

# %%
cols_to_scale = ['OpenDataLat', 'OpenDataLon', 'Occur_Hour', 'Occur_Minute']

scaler = StandardScaler()


scaled_data= crime[cols_to_scale] = scaler.fit_transform(crime[cols_to_scale])

scaled_data
# Out:
# array([[-0.1237915 , -0.30775653, -1.1409758 , -0.43007261],
#        [-0.1237915 , -0.30775653, -1.28911156,  0.36470898],
#        [-0.1237915 , -0.30775653, -0.84470426,  1.31844688],
#        ...,
#        [-1.27469077, -0.25777502,  0.48851766,  1.95427215],
#        [-0.89342393, -0.35564389,  0.63665342, -1.17186876],
#        [-0.56819218, -0.45302438,  0.48851766,  0.20575266]])

# %%
crime.describe().round(3)
# Out:
#        OffenseCount  OpenDataLat  OpenDataLon  Occur_Year  Occur_Month  \
# count     57034.000    57034.000    57034.000   57034.000    57034.000
# mean          1.001        0.000        0.000    2023.945        6.682
# std           0.034        1.000        1.000       0.893        3.429
# min           1.000       -3.023       -3.009    1951.000        1.000
# 25%           1.000       -0.474       -0.680    2024.000        4.000
# 50%           1.000       -0.124       -0.308    2024.000        7.000
# 75%           1.000        0.596        0.633    2024.000       10.000
# max           4.000        2.981        2.975    2024.000       12.000
#
#        Occur_Day  Occur_DayOfWeek  Occur_Hour  Occur_Minute
# count  57034.000        57034.000   57034.000     57034.000
# mean      15.784            3.023      -0.000         0.000
# std        8.872            1.992       1.000         1.000
# min        1.000            0.000      -1.882        -1.172
# 25%        8.000            1.000      -0.697        -1.172
# 50%       16.000            3.000       0.192        -0.059
# 75%       23.000            5.000       0.785         0.842
# max       31.000            6.000       1.525         1.954

# %% [markdown]
# Correlation values

# %%
le = LabelEncoder()

crime['OffenseCategory_Encoded'] = le.fit_transform(crime['OffenseCategory'])

# %%
crime_num = crime.select_dtypes(include = ['float64', 'int64']) 

target_col = 'OffenseCategory_Encoded'

crime_num_corr = crime_num.corr()[target_col][:-1] 

top_features = crime_num_corr[abs(crime_num_corr) > 0].sort_values(ascending=False) 

print("There is {} strongly correlated values with OffenseCategory:\n{}".format(len(top_features), top_features))
# Out:
# There is 5 strongly correlated values with OffenseCategory:
# Occur_Hour      0.031980
# OpenDataLat     0.029488
# OpenDataLon     0.014045
# OffenseCount    0.012481
# Occur_Minute   -0.082113
# Name: OffenseCategory_Encoded, dtype: float64

# %%
X = crime.drop(columns=columns_to_drop + ['OffenseCategory'], axis=1, errors='ignore')
Y = crime['OffenseCategory']


rare_classes_counts = Y.value_counts()
rare_classes_to_remove = rare_classes_counts[rare_classes_counts <= 1].index


valid_indices = ~Y.isin(rare_classes_to_remove)

X_filtered = X.loc[valid_indices]
Y_filtered = Y.loc[valid_indices]

print(f"تمت إزالة {len(Y) - len(Y_filtered)} صفوف تحتوي على فئات نادرة.")
print(f"شكل X بعد التصفية: {X_filtered.shape}")


categorical_cols = X_filtered.select_dtypes(include=['object']).columns
X_encoded = pd.get_dummies(X_filtered, columns=categorical_cols, drop_first=True)

X_train, X_test, Y_train, Y_test = train_test_split(X_encoded, Y_filtered, test_size=0.2, random_state=42, stratify=Y_filtered )

print('\nتم تقسيم البيانات بنجاح.')
print('حجم مجموعة التدريب (X_train):', X_train.shape)
print('حجم مجموعة الاختبار (X_test):', X_test.shape)
# Out:
# تمت إزالة 1 صفوف تحتوي على فئات نادرة.
# شكل X بعد التصفية: (57033, 16)
#
# تم تقسيم البيانات بنجاح.
# حجم مجموعة التدريب (X_train): (45626, 177)
# حجم مجموعة الاختبار (X_test): (11407, 177)

# %%
numerical_cols_for_scaling = ['OpenDataLat', 'OpenDataLon', 'OffenseCount', 
                               'Occur_Day', 'Occur_DayOfWeek'] 

scaler = StandardScaler()

X_train[numerical_cols_for_scaling] = scaler.fit_transform(X_train[numerical_cols_for_scaling])

X_test[numerical_cols_for_scaling] = scaler.transform(X_test[numerical_cols_for_scaling])

print("تم التوحيد القياسي للمتغيرات الرقمية بنجاح.")
# Out:
# تم التوحيد القياسي للمتغيرات الرقمية بنجاح.

# %% [markdown]
# ## Modeling And ALgorithm
# DecisionTree Classifier Algorithm

# %%
dt_model = DecisionTreeClassifier(criterion="entropy", max_depth = 4)
dt_model.fit(X_train, Y_train)

dt_predictions = dt_model.predict(X_test)
dt_accuracy = metrics.accuracy_score(Y_test, dt_predictions)

print(f"دقة نموذج Decision Tree: {dt_accuracy:.2f}")
# Out:
# دقة نموذج Decision Tree: 0.98

# %%
plot_tree(dt_model)
plt.show()

# %% [markdown]
# KNN Algorithm

# %%
k=20
knn_model = KNeighborsClassifier(n_neighbors=k)
knn_model.fit(X_train, Y_train)

# 2. التنبؤ والتقييم
knn_predictions = knn_model.predict(X_test)
knn_accuracy = metrics.accuracy_score(Y_test, knn_predictions)
print(f"دقة نموذج KNN: {knn_accuracy:.3f}")
# Out:
# دقة نموذج KNN: 0.989

# %%
print(classification_report(Y_test, knn_predictions))
# Out:
#                               precision    recall  f1-score   support
#
#      Animal Cruelty Offenses       0.00      0.00      0.00         9
#                        Arson       1.00      0.65      0.79        60
#             Assault Offenses       0.98      1.00      0.99      1588
#                     Burglary       0.97      1.00      0.98       919
#       Counterfeiting/Forgery       0.96      0.42      0.59        52
#       Drug/Narcotic Offenses       1.00      1.00      1.00       139
#                 Embezzlement       1.00      0.11      0.20         9
#          Extortion/Blackmail       0.00      0.00      0.00         8
#               Fraud Offenses       0.95      1.00      0.98       608
#            Homicide Offenses       0.00      0.00      0.00        13
#   Human Trafficking Offenses       0.00      0.00      0.00         4
#         Kidnapping/Abduction       0.00      0.00      0.00        13
#             Larceny Offenses       1.00      1.00      1.00      4965
#          Motor Vehicle Theft       0.99      1.00      1.00      1082
# Pornography/Obscene Material       1.00      0.50      0.67        14
#        Prostitution Offenses       0.98      1.00      0.99        52
#                      Robbery       1.00      1.00      1.00       226
#                 Sex Offenses       0.97      1.00      0.99       111
#     Stolen Property Offenses       0.00      0.00      0.00         5
#                    Vandalism       1.00      1.00      1.00      1365
#        Weapon Law Violations       1.00      1.00      1.00       165
#
#                     accuracy                           0.99     11407
#                    macro avg       0.70      0.60      0.63     11407
#                 weighted avg       0.98      0.99      0.99     11407
# c:\Users\hp\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\hp\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\hp\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
Ks = 10
acc = np.zeros((Ks))
std_acc = np.zeros((Ks))
for n in range(1,Ks+1):
    #Train Model and Predict  
    knn_model_n = KNeighborsClassifier(n_neighbors = n).fit(X_train,Y_train)
    yhat = knn_model_n.predict(X_test)
    acc[n-1] = accuracy_score(Y_test, yhat)
    std_acc[n-1] = np.std(yhat==Y_test)/np.sqrt(yhat.shape[0])

# %%
plt.plot(range(1,Ks+1),acc,'g')

plt.fill_between(range(1,Ks+1), acc - 1 * std_acc, acc + 1 * std_acc, alpha=0.10)

plt.legend(('Accuracy value', 'Standard Deviation'))
plt.ylabel('Model Accuracy')
plt.xlabel('Number of Neighbors (K)')
plt.tight_layout()
plt.show()

# %%
print( "The best accuracy was with", acc.max(), "with k =", acc.argmax()+1)
# Out:
# The best accuracy was with 0.9967563776628386 with k = 1

# %% [markdown]
# SVM Algorithm

# %%
param_grid = {
    'C': [10, 25, 50, 75],  
    'gamma': [0.01, 0.05, 0.1], 
    'kernel': ['rbf']
}

svm_grid = GridSearchCV(
    SVC(random_state=42), 
    param_grid, 
    cv=5, 
    scoring='accuracy', 
    n_jobs=-1
)

print("جاري تشغيل Grid Search للبحث عن أفضل معاملات SVM...")
svm_grid.fit(X_train, Y_train)

# استخراج النتائج
best_svm_model = svm_grid.best_estimator_
best_score = svm_grid.best_score_

print(f"\n✅ أفضل مجموعة معاملات لـ SVM: {svm_grid.best_params_}")
print(f"أفضل دقة عبر Cross-Validation: {best_score:.4f}")

# التقييم النهائي
final_test_accuracy = accuracy_score(Y_test, best_svm_model.predict(X_test))
print(f"دقة النموذج الأفضل على بيانات الاختبار: {final_test_accuracy:.4f}")

# %%
svm_model = SVC(C=10, gamma=0.01, kernel='rbf', random_state=42)
svm_model.fit(X_train, Y_train)
# Out:
# SVC(C=10, gamma=0.01, random_state=42)

# %%
svm_prediction=svm_model.predict(X_test)
svm_accuracy=accuracy_score(Y_test,svm_prediction)
print(f"الدقة الكلية (Accuracy): {svm_accuracy:.4f}")
print(classification_report(Y_test, svm_prediction))
# Out:
# الدقة الكلية (Accuracy): 0.9998
#                               precision    recall  f1-score   support
#
#      Animal Cruelty Offenses       1.00      1.00      1.00         9
#                        Arson       1.00      1.00      1.00        60
#             Assault Offenses       1.00      1.00      1.00      1588
#                     Burglary       1.00      1.00      1.00       919
#       Counterfeiting/Forgery       1.00      1.00      1.00        52
#       Drug/Narcotic Offenses       1.00      1.00      1.00       139
#                 Embezzlement       1.00      1.00      1.00         9
#          Extortion/Blackmail       1.00      1.00      1.00         8
#               Fraud Offenses       1.00      1.00      1.00       608
#            Homicide Offenses       1.00      1.00      1.00        13
#   Human Trafficking Offenses       1.00      1.00      1.00         4
#         Kidnapping/Abduction       1.00      1.00      1.00        13
#             Larceny Offenses       1.00      1.00      1.00      4965
#          Motor Vehicle Theft       1.00      1.00      1.00      1082
# Pornography/Obscene Material       1.00      1.00      1.00        14
#        Prostitution Offenses       1.00      1.00      1.00        52
#                      Robbery       1.00      1.00      1.00       226
#                 Sex Offenses       1.00      1.00      1.00       111
#     Stolen Property Offenses       1.00      1.00      1.00         5
#                    Vandalism       1.00      1.00      1.00      1365
#        Weapon Law Violations       1.00      1.00      1.00       165
#
#                     accuracy                           1.00     11407
#                    macro avg       1.00      1.00      1.00     11407
#                 weighted avg       1.00      1.00      1.00     11407

# %%
# التنبؤ على بيانات التدريب نفسها
svm_train_predictions = svm_model.predict(X_train)
svm_train_accuracy = metrics.accuracy_score(Y_train, svm_train_predictions)

print(f"دقة التدريب (Training Accuracy): {svm_train_accuracy:.4f}")
# Out:
# دقة التدريب (Training Accuracy): 1.0000

# %%
# 1. حساب مصفوفة الارتباك باستخدام نتائج نموذج SVM
cm = confusion_matrix(Y_test, svm_prediction)

# 2. رسم المصفوفة الحرارية (Heatmap)
plt.figure(figsize=(12, 10))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',  # 'd' لعرض الأرقام كأعداد صحيحة
    cmap='Blues', # يمكنك اختيار لون مناسب
    cbar=False,
    # يمكنك إضافة أسماء الفئات هنا إذا كانت متاحة لديك
    # xticklabels=class_names, 
    # yticklabels=class_names
)
plt.title('Confusion Matrix for Optimal SVM Model (Accuracy: 0.9998)')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
